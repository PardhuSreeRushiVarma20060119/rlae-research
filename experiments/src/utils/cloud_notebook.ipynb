# %% [markdown]
# # Research Paper Figures (Premium Modern)
#
# This notebook displays the final, high-quality figures generated with a Modern aesthetic (Sans-Serif, High Contrast).

# %% [markdown]
# ## Figure 1: Model Recoverability
# Comparison of KL Divergence between standard Weight Mutation (high error) and RLAE Reset (near-zero error).

# %%
from IPython.display import Image, display
display(Image(filename='paper_figures/Fig1_Recoverability_Modern.png'))

# %% [markdown]
# ## Figure 2: Reversibility Threshold Analysis
# Trace of KL Divergence across Elimination Rates ($\lambda$), showing the deterministic recovery zone (shaded green).

# %%
display(Image(filename='paper_figures/Fig2_Elimination_Sweep_Modern.png'))

# %% [markdown]
# ## Figure 3: Recoverability Factor (RF) Score
# Binary comparison demonstrating RLAE's ability to achieve 100% recovery.

# %%
display(Image(filename='paper_figures/Fig3_RF_Proof_Modern.png'))

# %% [markdown]
# ## Figure 4: Baseline Identity Stability
# Tracking Shannon Entropy of the base model across sprints to prove identity retention.

# %%
display(Image(filename='paper_figures/Fig4_Baseline_Stability_Modern.png'))
