# %% [markdown]
# # 🛡️ RLAE & SVAR: Canonical Research Environment
#
# This notebook implements the full research lifecycle for **Runtime Low‑Rank Adaptive Environments (RLAE)** and **Structural Variance Analysis for Robustness (SVAR)**.
#
# ## 📖 Paradigms in Scope
# - **Frozen Core Invariance:** The base model foundation is immutable.
# - **Behavioral Sandboxing:** RL updates apply only to swappable LoRA artifacts.
# - **Runtime Governance:** Behaviors can be dynamically mounted, replaced, or destroyed.
# - **Diagnostic Surface:** Evaluation via structural perturbation (SVAR) and identity leakage detection.

# %% [markdown]
# ## Step 0: Deployment & Extraction
# **On your local machine, zip the folder: ```zip -r research.zip experiments/```.**
#
# **In a Colab cell, run:**

# %%
# 1. Upload your 'research.zip' using the file sidebar
# 2. Extract the core
# !unzip research.zip
# Out:
# Archive:  research.zip
#   inflating: .vscode/settings.json
#   inflating: arts/RLAE&SVAR.png
#   inflating: arts/World of REVA4RE.png
#   inflating: colab-experiments/README.md
#   inflating: colab-experiments/Stage1_Experiments.ipynb
#   inflating: colab-experiments/Stage2_ILS_Experiment_Test1.ipynb
#   inflating: colab-experiments/Stage2_ILS_Experiment_Test2.ipynb
#   inflating: experiments/cloud_notebook.ipynb
#   inflating: experiments/experiments-bundle-old.zip
#   inflating: experiments/GPU_SAFE_SHUTDOWN.md
#   inflating: experiments/README.md
#   inflating: experiments/requirements.txt
#   inflating: experiments/run_pipeline.sh
#   inflating: experiments/run_stress_test.sh
#   inflating: experiments/WALKTHROUGH.md
#   inflating: experiments/data/fixed_prompts.json
#   inflating: experiments/data/README.md
#   inflating: experiments/data/training_data.json
#   inflating: experiments/logs/README.md
#   inflating: experiments/logs/Sprint-1/exp1_results.json
#   inflating: experiments/logs/Sprint-1/exp2_rlae_results.json
#   inflating: experiments/logs/Sprint-1/exp3_svar_results.json
#   inflating: experiments/logs/Sprint-1/exp4_stress_results.json
#   inflating: experiments/logs/Sprint-1/exp5_comparison_results.json
#   inflating: experiments/models/README.md
#   inflating: experiments/models/lora_rl/adapter_config.json
#   inflating: experiments/models/lora_rl/adapter_model.safetensors
#   inflating: experiments/models/lora_rl/added_tokens.json
#   inflating: experiments/models/lora_rl/chat_template.jinja
#   inflating: experiments/models/lora_rl/merges.txt
#   inflating: experiments/models/lora_rl/README.md
#   inflating: experiments/models/lora_rl/special_tokens_map.json
#   inflating: experiments/models/lora_rl/tokenizer_config.json
#   inflating: experiments/models/lora_rl/tokenizer.json
#   inflating: experiments/models/lora_rl/training_args.bin
#   inflating: experiments/models/lora_rl/vocab.json
#   inflating: experiments/models/lora_sft/adapter_config.json
#   inflating: experiments/models/lora_sft/adapter_model.safetensors
#   inflating: experiments/models/lora_sft/README.md
#   inflating: experiments/src/README.md
#   inflating: experiments/src/analysis/analyze_results.py
#   inflating: experiments/src/analysis/README.md
#   inflating: experiments/src/exp1_reset/1_baseline.py
#   inflating: experiments/src/exp1_reset/2_train_sft.py
#   inflating: experiments/src/exp1_reset/3_train_rl.py
#   inflating: experiments/src/exp1_reset/4_verify_reset.py
#   inflating: experiments/src/exp1_reset/README.md
#   inflating: experiments/src/exp2_rlae/elimination_test.py
#   inflating: experiments/src/exp2_rlae/README.md
#   inflating: experiments/src/exp3_svar/perturbation.py
#   inflating: experiments/src/exp3_svar/README.md
#   inflating: experiments/src/exp4_stress/README.md
#   inflating: experiments/src/exp4_stress/stress_single_run.py
#   inflating: experiments/src/exp5_comparison/irreversibility_test.py
#   inflating: experiments/src/utils/browser_app.py
#   inflating: experiments/src/utils/metrics.py
#   inflating: experiments/src/utils/model.py
#   inflating: experiments/src/utils/README.md
#   inflating: experiments/src/utils/__pycache__/browser_app.cpython-311.pyc
#   inflating: experiments/src/utils/__pycache__/metrics.cpython-311.pyc
#   inflating: experiments/src/verification/README.md
#   inflating: experiments/src/verification/robustness_suite.py
#   inflating: experiments/src/verification/__pycache__/robustness_suite.cpython-311.pyc
#   inflating: project-scope/README.md
#   inflating: project-scope/rlae-svar-doc.pdf
#   inflating: project-scope/svar-doc.pdf
#   inflating: reportdocx/README.md
#   inflating: reportdocx/report_2025-12-31.docx
#   inflating: reportdocx/alldocx/rlae-doc.md
#   inflating: reportdocx/alldocx/svar-doc.md
#   inflating: reports/README.md
#   inflating: reports/report_2025-12-31.md
#   inflating: reports/report_2025-12-31.pdf
#   inflating: CONTRIBUTING.md
#   inflating: LICENSE
#   inflating: README.md

# %%
# %cd experiments
# Out:
# /content/experiments

# %% [markdown]
# ## 🛠️ Step 1: Environment Mounting
# Install dependencies and verify the **Frozen Core** (GPU) status.
#
# Run this in a cell to install the canonical stack (optimized for T4):

# %%
# !pip install -q -r requirements.txt
# !pip install -q gradio psutil

# %%
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Frozen Core Device: {torch.cuda.get_device_name(0)}")
    print(f"Memory Available: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB") # Should show ~15-16 GB on a T4
# Out:
# CUDA Available: True
# Frozen Core Device: Tesla T4
# Memory Available: 15.83 GB

# %% [markdown]
# # 🧪 Experiment 1: Reset Integrity & Training Pipeline
# Goal: Detect **Identity Leakage**. We train a behavioral environment and then attempt to prove its total reversibility.
#
# ## Step 2: The Research Pipeline (Sequential)
# Execute these commands in separate cells to build the behavioral artifacts:
#
# 1. Establish Core Baseline:

# %%
# Phase 1: Establish Frozen Core Baseline
# !python src/exp1_reset/1_baseline.py
# Out:
# 2026-01-10 16:27:02.537999: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768062422.566155    8876 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768062422.574378    8876 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768062422.595447    8876 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768062422.595472    8876 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768062422.595476    8876 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768062422.595481    8876 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-10 16:27:02.600087: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# === STARTING EXPERIMENT 1.B: BASELINE RUN (Hardened) ===
# GPU Memory: 0.00MB allocated, 0.00MB reserved
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:14<00:00,  7.22s/it]
# Base model loaded and FROZEN.
# Processing p1...
# Processing p2...
# Processing p3...
# Processing p4...
# Processing p5...
# Processing p6...
# Processing p7...
# Processing p8...
# Processing p9...
# Processing p10...
# === BASELINE RUN COMPLETE ===

# %% [markdown]
# 2. Mount Behavioral Environment (SFT + RL):

# %%
# Phase 2: Behavioral Mounting (SFT Training)
# !python src/exp1_reset/2_train_sft.py
# Out:
# 2026-01-10 16:28:47.552010: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768062527.571780    9324 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768062527.577961    9324 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768062527.604152    9324 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768062527.604183    9324 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768062527.604188    9324 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768062527.604193    9324 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-10 16:28:47.608935: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# === STARTING EXPERIMENT 1.C: LoRA SFT TRAINING ===
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:13<00:00,  6.77s/it]
# Base model loaded and FROZEN.
# Attaching NEW LoRA adapters...
# trainable params: 1,843,200 || all params: 3,087,781,888 || trainable%: 0.0597
# Adding EOS to train dataset: 100% 30/30 [00:00<00:00, 819.50 examples/s]
# Tokenizing train dataset: 100% 30/30 [00:00<00:00, 613.67 examples/s]
# Truncating train dataset: 100% 30/30 [00:00<00:00, 3710.57 examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# {'loss': 2.5765, 'grad_norm': 2.4135634899139404, 'learning_rate': 0.0002, 'entropy': 1.0238936692476273, 'num_tokens': 310.0, 'mean_token_accuracy': 0.5629982128739357, 'epoch': 0.13}
# {'loss': 2.5331, 'grad_norm': 2.8838419914245605, 'learning_rate': 0.00019166666666666667, 'entropy': 1.0306220948696136, 'num_tokens': 589.0, 'mean_token_accuracy': 0.6040463894605637, 'epoch': 0.27}
# {'loss': 2.5989, 'grad_norm': 2.435772657394409, 'learning_rate': 0.00018333333333333334, 'entropy': 1.1778032779693604, 'num_tokens': 867.0, 'mean_token_accuracy': 0.5311380550265312, 'epoch': 0.4}
# {'loss': 2.2986, 'grad_norm': 2.6883933544158936, 'learning_rate': 0.000175, 'entropy': 1.0942524075508118, 'num_tokens': 1152.0, 'mean_token_accuracy': 0.6162292659282684, 'epoch': 0.53}
# {'loss': 2.0171, 'grad_norm': 2.1355581283569336, 'learning_rate': 0.0001666666666666667, 'entropy': 1.0728724896907806, 'num_tokens': 1476.0, 'mean_token_accuracy': 0.6659537553787231, 'epoch': 0.67}
# {'loss': 1.8152, 'grad_norm': 2.2597732543945312, 'learning_rate': 0.00015833333333333332, 'entropy': 1.0003435462713242, 'num_tokens': 1789.0, 'mean_token_accuracy': 0.6652353852987289, 'epoch': 0.8}
# {'loss': 1.7194, 'grad_norm': 2.1535565853118896, 'learning_rate': 0.00015000000000000001, 'entropy': 1.1700776517391205, 'num_tokens': 2053.0, 'mean_token_accuracy': 0.6828792989253998, 'epoch': 0.93}
# {'loss': 1.5353, 'grad_norm': 1.9383714199066162, 'learning_rate': 0.00014166666666666668, 'entropy': 0.9948525726795197, 'num_tokens': 2215.0, 'mean_token_accuracy': 0.684974730014801, 'epoch': 1.0}
# {'loss': 1.7261, 'grad_norm': 1.8972094058990479, 'learning_rate': 0.00013333333333333334, 'entropy': 1.3548291325569153, 'num_tokens': 2512.0, 'mean_token_accuracy': 0.6430125087499619, 'epoch': 1.13}
# {'loss': 1.5202, 'grad_norm': 1.9179006814956665, 'learning_rate': 0.000125, 'entropy': 1.256682276725769, 'num_tokens': 2817.0, 'mean_token_accuracy': 0.6748903542757034, 'epoch': 1.27}
# {'loss': 1.5672, 'grad_norm': 1.9692715406417847, 'learning_rate': 0.00011666666666666668, 'entropy': 1.263116180896759, 'num_tokens': 3115.0, 'mean_token_accuracy': 0.7020387351512909, 'epoch': 1.4}
# {'loss': 1.4167, 'grad_norm': 1.4965282678604126, 'learning_rate': 0.00010833333333333333, 'entropy': 1.3036799728870392, 'num_tokens': 3411.0, 'mean_token_accuracy': 0.6810868382453918, 'epoch': 1.53}
# {'loss': 1.4429, 'grad_norm': 1.932405710220337, 'learning_rate': 0.0001, 'entropy': 1.3458034694194794, 'num_tokens': 3709.0, 'mean_token_accuracy': 0.7158560156822205, 'epoch': 1.67}
# {'loss': 1.6115, 'grad_norm': 1.5702502727508545, 'learning_rate': 9.166666666666667e-05, 'entropy': 1.44160795211792, 'num_tokens': 4011.0, 'mean_token_accuracy': 0.6658005863428116, 'epoch': 1.8}
# {'loss': 1.3622, 'grad_norm': 1.7229149341583252, 'learning_rate': 8.333333333333334e-05, 'entropy': 1.247674971818924, 'num_tokens': 4291.0, 'mean_token_accuracy': 0.7392430752515793, 'epoch': 1.93}
# {'loss': 1.6469, 'grad_norm': 1.8714537620544434, 'learning_rate': 7.500000000000001e-05, 'entropy': 1.5459622740745544, 'num_tokens': 4430.0, 'mean_token_accuracy': 0.6062899827957153, 'epoch': 2.0}
# {'loss': 1.3073, 'grad_norm': 1.4321627616882324, 'learning_rate': 6.666666666666667e-05, 'entropy': 1.1838580816984177, 'num_tokens': 4763.0, 'mean_token_accuracy': 0.7264779508113861, 'epoch': 2.13}
# {'loss': 1.2736, 'grad_norm': 1.8717947006225586, 'learning_rate': 5.833333333333334e-05, 'entropy': 1.276976615190506, 'num_tokens': 5064.0, 'mean_token_accuracy': 0.7486182898283005, 'epoch': 2.27}
# {'loss': 1.3347, 'grad_norm': 1.5104840993881226, 'learning_rate': 5e-05, 'entropy': 1.3837598264217377, 'num_tokens': 5355.0, 'mean_token_accuracy': 0.7426587343215942, 'epoch': 2.4}
# {'loss': 1.408, 'grad_norm': 1.7369463443756104, 'learning_rate': 4.166666666666667e-05, 'entropy': 1.3856323957443237, 'num_tokens': 5641.0, 'mean_token_accuracy': 0.7338132262229919, 'epoch': 2.53}
# {'loss': 1.259, 'grad_norm': 1.5799564123153687, 'learning_rate': 3.3333333333333335e-05, 'entropy': 1.2349087595939636, 'num_tokens': 5932.0, 'mean_token_accuracy': 0.7479821890592575, 'epoch': 2.67}
# {'loss': 1.3182, 'grad_norm': 1.7473703622817993, 'learning_rate': 2.5e-05, 'entropy': 1.328695684671402, 'num_tokens': 6216.0, 'mean_token_accuracy': 0.7388022691011429, 'epoch': 2.8}
# {'loss': 1.5831, 'grad_norm': 1.922192096710205, 'learning_rate': 1.6666666666666667e-05, 'entropy': 1.476059764623642, 'num_tokens': 6490.0, 'mean_token_accuracy': 0.6929063051939011, 'epoch': 2.93}
# {'loss': 1.1335, 'grad_norm': 1.6370505094528198, 'learning_rate': 8.333333333333334e-06, 'entropy': 1.3058568835258484, 'num_tokens': 6645.0, 'mean_token_accuracy': 0.7815735042095184, 'epoch': 3.0}
# {'train_runtime': 81.0699, 'train_samples_per_second': 1.11, 'train_steps_per_second': 0.296, 'train_loss': 1.6668815811475117, 'epoch': 3.0}
# 100% 24/24 [01:21<00:00,  3.38s/it]
# Saving SFT adapter to /content/experiments/src/exp1_reset/../../models/lora_sft
# === SFT TRAINING COMPLETE ===

# %%
# Phase 3: Adaptive Environment Optimization (RL Training)
# !python src/exp1_reset/3_train_rl.py
# Out:
# 2026-01-10 16:33:37.921874: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768062817.966757   10577 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768062817.977598   10577 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768062818.019458   10577 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768062818.019492   10577 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768062818.019500   10577 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768062818.019506   10577 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-10 16:33:38.026253: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# === STARTING EXPERIMENT 1.D: LoRA RL (DPO) TRAINING ===
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:15<00:00,  7.57s/it]
# Base model loaded and FROZEN.
# Extracting prompt in train dataset: 100% 2/2 [00:00<00:00, 69.80 examples/s]
# Applying chat template to train dataset: 100% 2/2 [00:00<00:00, 716.55 examples/s]
# Tokenizing train dataset: 100% 2/2 [00:00<00:00, 243.37 examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#   0% 0/3 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:85: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# {'loss': 0.391, 'grad_norm': 6.9576592445373535, 'learning_rate': 1e-05, 'rewards/chosen': 1.3413918018341064, 'rewards/rejected': 0.6022446155548096, 'rewards/accuracies': 1.0, 'rewards/margins': 0.7391471862792969, 'logps/chosen': -84.87208557128906, 'logps/rejected': -64.58544921875, 'logits/chosen': 0.07558460533618927, 'logits/rejected': 0.3861656188964844, 'epoch': 1.0}
# {'loss': 0.3742, 'grad_norm': 6.373871803283691, 'learning_rate': 6.666666666666667e-06, 'rewards/chosen': 1.4168102741241455, 'rewards/rejected': 0.6246936917304993, 'rewards/accuracies': 1.0, 'rewards/margins': 0.7921165823936462, 'logps/chosen': -84.11790466308594, 'logps/rejected': -64.3609619140625, 'logits/chosen': 0.0740777999162674, 'logits/rejected': 0.3879850208759308, 'epoch': 2.0}
# {'loss': 0.3501, 'grad_norm': 5.8168721199035645, 'learning_rate': 3.3333333333333333e-06, 'rewards/chosen': 1.451907753944397, 'rewards/rejected': 0.5825565457344055, 'rewards/accuracies': 1.0, 'rewards/margins': 0.8693512082099915, 'logps/chosen': -83.76692962646484, 'logps/rejected': -64.78233337402344, 'logits/chosen': 0.07440917193889618, 'logits/rejected': 0.38533177971839905, 'epoch': 3.0}
# {'train_runtime': 6.8464, 'train_samples_per_second': 0.876, 'train_steps_per_second': 0.438, 'train_loss': 0.37174879511197406, 'epoch': 3.0}
# 100% 3/3 [00:06<00:00,  2.28s/it]
# Saving RL adapter to /content/experiments/src/exp1_reset/../../models/lora_rl
# === RL TRAINING COMPLETE ===

# %% [markdown]
# ### 🛑 REVERSIBILITY CHECK (Hard Reset)
# To validate **Principle 6 (Killability)**:
# 1. Go to **Runtime** > **Restart Session**.
# 2. Re-run Step 0 (Imports only).
# 3. Run the verification cell below.

# %%
# Phase 4: Detect Identity Leakage (Post-Unmount Check)
# !python src/exp1_reset/4_verify_reset.py
# Out:
# 2026-01-10 16:37:15.302628: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768063035.325047   11589 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768063035.332056   11589 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768063035.349554   11589 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768063035.349579   11589 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768063035.349584   11589 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768063035.349588   11589 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-10 16:37:15.354126: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# === STARTING EXPERIMENT 1.E: POST-RESET CHECK (Hardened) ===
# GPU Memory: 0.00MB allocated, 0.00MB reserved
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:13<00:00,  6.87s/it]
# Base model loaded and FROZEN.
# Processing p1...
#        - ILS: 0.0080 (HEALTHY)
# Processing p2...
#        - ILS: 0.0300 (HEALTHY)
# Processing p3...
#        - ILS: 0.0108 (HEALTHY)
# Processing p4...
#        - ILS: 0.0127 (HEALTHY)
# Processing p5...
#        - ILS: 0.0424 (HEALTHY)
# Processing p6...
#        - ILS: 0.0654 (LEAKAGE DETECTED)
# Processing p7...
#        - ILS: 0.0580 (LEAKAGE DETECTED)
# Processing p8...
#        - ILS: 0.0112 (HEALTHY)
# Processing p9...
#        - ILS: 0.0160 (HEALTHY)
# Processing p10...
#        - ILS: 0.0052 (HEALTHY)
# === POST-RESET CHECK COMPLETE ===

# %% [markdown]
# ## 🧪 Experiment 2: RLAE Core (Behavioral Elimination)
# Goal: Measure behavioral collapse as the environment is gradually thinned. Validates that intelligence is a structural process.

# %%
# !python src/exp2_rlae/elimination_test.py
# Out:
# 2026-01-10 17:16:21.034589: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768065381.066476   21287 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768065381.075776   21287 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768065381.110147   21287 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768065381.110174   21287 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768065381.110179   21287 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768065381.110183   21287 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-10 17:16:21.115134: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# --- Running RLAE_ELIM_0.0 (Hardened) ---
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:19<00:00,  9.69s/it]
# Base model loaded and FROZEN.
# --- Running RLAE_ELIM_0.2 (Hardened) ---
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:17<00:00,  8.71s/it]
# Base model loaded and FROZEN.
# Eliminating Adapters (Magnitude-based): ratio=0.2
# --- Running RLAE_ELIM_0.4 (Hardened) ---
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:18<00:00,  9.42s/it]
# Base model loaded and FROZEN.
# Eliminating Adapters (Magnitude-based): ratio=0.4
# --- Running RLAE_ELIM_0.6 (Hardened) ---
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:14<00:00,  7.18s/it]
# Base model loaded and FROZEN.
# Eliminating Adapters (Magnitude-based): ratio=0.6
# --- Running RLAE_ELIM_0.8 (Hardened) ---
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:19<00:00,  9.71s/it]
# Base model loaded and FROZEN.
# Eliminating Adapters (Magnitude-based): ratio=0.8
# --- Running RLAE_ELIM_1.0 (Hardened) ---
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:12<00:00,  6.16s/it]
# Base model loaded and FROZEN.
# Eliminating Adapters (Magnitude-based): ratio=1.0

# %% [markdown]
# ## 🧪 Experiment 3: SVAR (Diagnostic Stability Envelopes)
# **Structural Variance Analysis For Robustness**
#
# This phase applies adversarial stressors directly to the behavioral structure to test stability envelopes.
#
# Goal: Subject the behaviors to structural perturbations (noise, dropout) to find brittleness.

# %%
# !python src/exp3_svar/perturbation.py
# Out:
# 2026-01-10 17:32:26.650912: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768066346.863452   25321 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768066346.922836   25321 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768066347.330765   25321 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768066347.330807   25321 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768066347.330814   25321 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768066347.330821   25321 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-10 17:32:27.376071: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# --- Running SVAR_none_0.0 ---
# GPU Memory: 0.00MB allocated, 0.00MB reserved
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:09<00:00,  4.93s/it]
# Base model loaded and FROZEN.
# --- Running SVAR_layer_dropout_0.25 ---
# GPU Memory: 15.87MB allocated, 5914.00MB reserved
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:02<00:00,  1.07s/it]
# Base model loaded and FROZEN.
# Applying Perturbation: layer_dropout level=0.25
# --- Running SVAR_weight_decay_0.1 ---
# GPU Memory: 15.87MB allocated, 5916.00MB reserved
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:02<00:00,  1.05s/it]
# Base model loaded and FROZEN.
# Applying Perturbation: weight_decay level=0.1
# --- Running SVAR_noise_0.01 ---
# GPU Memory: 15.87MB allocated, 5920.00MB reserved
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:19<00:00,  9.60s/it]
# Base model loaded and FROZEN.
# Applying Perturbation: noise level=0.01
# --- Running SVAR_adversarial_0.05 ---
# GPU Memory: 15.87MB allocated, 5922.00MB reserved
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:14<00:00,  7.33s/it]
# Base model loaded and FROZEN.
# Applying Perturbation: adversarial level=0.05

# %% [markdown]
# ## 🧪 Experiment 4: Runtime Reliability (Stress Test)
# Goal: Ensure GPU stability during high-intensity behavioral inference.

# %%
# !python src/exp4_stress/stress_single_run.py
# Out:
# 2026-01-10 17:53:54.724137: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768067634.800146   30685 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768067634.825801   30685 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768067634.881409   30685 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768067634.881455   30685 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768067634.881463   30685 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768067634.881470   30685 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-10 17:53:54.893462: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# === STRESS TEST ITERATION 0 ===
# GPU Memory: 0.00MB allocated, 0.00MB reserved
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:23<00:00, 11.81s/it]
# Base model loaded and FROZEN.
# Starting 100 inference cycles...
# Progress: 0/100...
# Progress: 10/100...
# Progress: 20/100...
# Progress: 30/100...
# Progress: 40/100...
# Progress: 50/100...
# Progress: 60/100...
# Progress: 70/100...
# Progress: 80/100...
# Progress: 90/100...
# === ITERATION 0 COMPLETE (100 steps) ===

# %% [markdown]
# ## 🧪 Experiment 5: Comparative Proof (Structural Mutation vs. RLAE Method)
# Goal: Scientifically prove the structural irreversibility of traditional weight adaptation by comparing Unstructured/Structured Mutation against the RLAE native rollback mechanism.

# %%
# !python src/exp5_comparison/irreversibility_test.py
# Out:
# 2026-01-10 19:38:05.622222: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768073885.806322   56924 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768073885.857288   56924 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768073886.252012   56924 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768073886.252049   56924 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768073886.252053   56924 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768073886.252061   56924 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-10 19:38:06.297540: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:04<00:00,  2.44s/it]
# Base model loaded and FROZEN.
#
# ============================================================
#  SECTION 1: UNSTRUCTURED WEIGHT MUTATION (SIMULATED NOISE)
# ============================================================
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:01<00:00,  1.01it/s]
# Base model loaded and FROZEN.
# !!! CRITICAL: Simulating Direct Weight Mutation (Intensity=0.01) !!!
# SECTION 1: Generating Weight Mutated Outputs from the Model (Identity Scars)
# SECTION 1 Peak KL (Leakage): 10.2326
#
# SEC1: Attempting Identity Restoration (Native Operation)...
# --- [RESTORE LOGIC]: Identity is 'baked-in'. No reversal operator exists.
# !!! [RESTORE RESULT]: [FAILED] - Identity Scars persist. KL Divergence: 10.2326 !!!
# !!! SECTION 1 RECOVERABILITY FACTOR: 0.00% !!!
#
# ============================================================
#  SECTION 2: STRUCTURED WEIGHT MUTATION (REAL GRADIENTS)
# ============================================================
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:02<00:00,  1.09s/it]
# Base model loaded and FROZEN.
# !!! CRITICAL: Executing Real Gradient-Based Mutation (Steps=10) !!!
# --- [TRAINING ENGINE]: Optimizing weights for task adaptation...
#     Step 1/10 | Loss: 2.6112
#     Step 2/10 | Loss: 1.0287
#     Step 3/10 | Loss: 1.1072
#     Step 4/10 | Loss: 0.7236
#     Step 5/10 | Loss: 1.1023
#     Step 6/10 | Loss: 0.7991
#     Step 7/10 | Loss: 1.1429
#     Step 8/10 | Loss: 0.8476
#     Step 9/10 | Loss: 0.8224
#     Step 10/10 | Loss: 1.1426
# --- [TRAINING ENGINE]: Mutation Complete. Core weights have been permanently drifted.
# SECTION 2: Probing Identity Scars from Gradient-Based Mutation...
# SECTION 2 Peak KL (Leakage from Training): 0.2011
#
# SEC2: Attempted identity restoration under constrained operations...
# --- [RESTORE LOGIC]: Core weights have been permuted by optimizer. No native 'Unlearn' operation.
# !!! [RESTORE RESULT]: [FAILED] - Gradient-based scars persist. KL Divergence: 0.2011 !!!
# !!! SECTION 2 RECOVERABILITY FACTOR: 0.00% !!!
#
# ============================================================
#  SECTION 3: RLAE METHOD (ADAPTIVE ENVIRONMENT)
# ============================================================
# Loading Base Model: Qwen/Qwen2.5-3B-Instruct
# Loading checkpoint shards: 100% 2/2 [00:02<00:00,  1.21s/it]
# Base model loaded and FROZEN.
# RLAE: Adapter active.
# SECTION 3: Probing Adaptive State Behavioral Manifestations...
# SECTION 3 Peak KL (Active Behavior): 0.0210
# RLAE: Activating Kill Switch (Unmounting Adapter)...
# SECTION 3: RLAE Reset - Probing Base State (Verifying Identity Restoration)...
# !!! [RESTORE RESULT]: [PASS] - Identity perfectly recovered. KL Divergence: 0.0000 !!!
# !!! SECTION 3 RECOVERABILITY FACTOR: 100.00% !!!

# %%
# !zip -r Sprint-2-logs.zip logs/Sprint-2
# Out:
#   adding: logs/Sprint-2/ (stored 0%)
#   adding: logs/Sprint-2/exp4_singlerun_stress_results.json (deflated 85%)
#   adding: logs/Sprint-2/exp5_comparison_results.json (deflated 75%)
#   adding: logs/Sprint-2/exp1_postreset_results.json (deflated 78%)
#   adding: logs/Sprint-2/exp2_rlae_results.json (deflated 79%)
#   adding: logs/Sprint-2/.ipynb_checkpoints/ (stored 0%)
#   adding: logs/Sprint-2/exp3_svar_results.json (deflated 76%)
#   adding: logs/Sprint-2/exp1_results.json (deflated 78%)

# %%
# %cd ..
# Out:
# /content

# %%
# !zip -r research.zip reva4/
# Out:
#   adding: reva4/ (stored 0%)
#   adding: reva4/README.md (deflated 52%)
#   adding: reva4/reports/ (stored 0%)
#   adding: reva4/reports/report_2025-12-31.md (deflated 50%)
#   adding: reva4/reports/README.md (deflated 41%)
#   adding: reva4/reports/report_2025-12-31.pdf (deflated 63%)
#   adding: reva4/arts/ (stored 0%)
#   adding: reva4/arts/RLAE&SVAR.png (deflated 24%)
#   adding: reva4/arts/World of REVA4RE.png (deflated 3%)
#   adding: reva4/LICENSE (deflated 66%)
#   adding: reva4/CONTRIBUTING.md (deflated 52%)
#   adding: reva4/experiments/ (stored 0%)
#   adding: reva4/experiments/experiments-bundle-old.zip (stored 0%)
#   adding: reva4/experiments/data/ (stored 0%)
#   adding: reva4/experiments/data/README.md (deflated 41%)
#   adding: reva4/experiments/data/fixed_prompts.json (deflated 57%)
#   adding: reva4/experiments/data/training_data.json (deflated 67%)
#   adding: reva4/experiments/cloud_notebook.ipynb (deflated 76%)
#   adding: reva4/experiments/run_pipeline.sh (deflated 45%)
#   adding: reva4/experiments/README.md (deflated 56%)
#   adding: reva4/experiments/requirements.txt (deflated 33%)
#   adding: reva4/experiments/GPU_SAFE_SHUTDOWN.md (deflated 43%)
#   adding: reva4/experiments/Sprint-2-logs.zip (stored 0%)
#   adding: reva4/experiments/run_stress_test.sh (deflated 36%)
#   adding: reva4/experiments/models/ (stored 0%)
#   adding: reva4/experiments/models/README.md (deflated 42%)
#   adding: reva4/experiments/models/lora_sft/ (stored 0%)
#   adding: reva4/experiments/models/lora_sft/adapter_config.json (deflated 56%)
#   adding: reva4/experiments/models/lora_sft/README.md (deflated 65%)
#   adding: reva4/experiments/models/lora_sft/adapter_model.safetensors (deflated 8%)
#   adding: reva4/experiments/models/lora_rl/ (stored 0%)
#   adding: reva4/experiments/models/lora_rl/adapter_config.json (deflated 56%)
#   adding: reva4/experiments/models/lora_rl/merges.txt (deflated 57%)
#   adding: reva4/experiments/models/lora_rl/vocab.json (deflated 61%)
#   adding: reva4/experiments/models/lora_rl/README.md (deflated 65%)
#   adding: reva4/experiments/models/lora_rl/training_args.bin (deflated 54%)
#   adding: reva4/experiments/models/lora_rl/chat_template.jinja (deflated 71%)
#   adding: reva4/experiments/models/lora_rl/tokenizer.json (deflated 81%)
#   adding: reva4/experiments/models/lora_rl/tokenizer_config.json (deflated 89%)
#   adding: reva4/experiments/models/lora_rl/added_tokens.json (deflated 67%)
#   adding: reva4/experiments/models/lora_rl/adapter_model.safetensors (deflated 8%)
#   adding: reva4/experiments/models/lora_rl/special_tokens_map.json (deflated 69%)
#   adding: reva4/experiments/WALKTHROUGH.md (deflated 54%)
#   adding: reva4/experiments/src/ (stored 0%)
#   adding: reva4/experiments/src/exp4_stress/ (stored 0%)
#   adding: reva4/experiments/src/exp4_stress/README.md (deflated 28%)
#   adding: reva4/experiments/src/exp4_stress/stress_single_run.py (deflated 59%)
#   adding: reva4/experiments/src/analysis/ (stored 0%)
#   adding: reva4/experiments/src/analysis/README.md (deflated 30%)
#   adding: reva4/experiments/src/analysis/analyze_results.py (deflated 59%)
#   adding: reva4/experiments/src/README.md (deflated 40%)
#   adding: reva4/experiments/src/exp1_reset/ (stored 0%)
#   adding: reva4/experiments/src/exp1_reset/2_train_sft.py (deflated 53%)
#   adding: reva4/experiments/src/exp1_reset/README.md (deflated 39%)
#   adding: reva4/experiments/src/exp1_reset/3_train_rl.py (deflated 53%)
#   adding: reva4/experiments/src/exp1_reset/4_verify_reset.py (deflated 59%)
#   adding: reva4/experiments/src/exp1_reset/1_baseline.py (deflated 58%)
#   adding: reva4/experiments/src/utils/ (stored 0%)
#   adding: reva4/experiments/src/utils/README.md (deflated 28%)
#   adding: reva4/experiments/src/utils/__pycache__/ (stored 0%)
#   adding: reva4/experiments/src/utils/__pycache__/browser_app.cpython-311.pyc (deflated 53%)
#   adding: reva4/experiments/src/utils/__pycache__/metrics.cpython-311.pyc (deflated 51%)
#   adding: reva4/experiments/src/utils/__pycache__/metrics.cpython-312.pyc (deflated 49%)
#   adding: reva4/experiments/src/utils/__pycache__/model.cpython-312.pyc (deflated 46%)
#   adding: reva4/experiments/src/utils/model.py (deflated 62%)
#   adding: reva4/experiments/src/utils/metrics.py (deflated 63%)
#   adding: reva4/experiments/src/utils/browser_app.py (deflated 63%)
#   adding: reva4/experiments/src/exp2_rlae/ (stored 0%)
#   adding: reva4/experiments/src/exp2_rlae/README.md (deflated 36%)
#   adding: reva4/experiments/src/exp2_rlae/elimination_test.py (deflated 61%)
#   adding: reva4/experiments/src/exp5_comparison/ (stored 0%)
#   adding: reva4/experiments/src/exp5_comparison/irreversibility_test.py (deflated 71%)
#   adding: reva4/experiments/src/verification/ (stored 0%)
#   adding: reva4/experiments/src/verification/README.md (deflated 30%)
#   adding: reva4/experiments/src/verification/robustness_suite.py (deflated 65%)
#   adding: reva4/experiments/src/verification/__pycache__/ (stored 0%)
#   adding: reva4/experiments/src/verification/__pycache__/robustness_suite.cpython-311.pyc (deflated 54%)
#   adding: reva4/experiments/src/exp3_svar/ (stored 0%)
#   adding: reva4/experiments/src/exp3_svar/README.md (deflated 37%)
#   adding: reva4/experiments/src/exp3_svar/perturbation.py (deflated 63%)
#   adding: reva4/experiments/logs/ (stored 0%)
#   adding: reva4/experiments/logs/Sprint-2/ (stored 0%)
#   adding: reva4/experiments/logs/Sprint-2/exp4_singlerun_stress_results.json (deflated 85%)
#   adding: reva4/experiments/logs/Sprint-2/exp5_comparison_results.json (deflated 75%)
#   adding: reva4/experiments/logs/Sprint-2/exp1_postreset_results.json (deflated 78%)
#   adding: reva4/experiments/logs/Sprint-2/exp2_rlae_results.json (deflated 79%)
#   adding: reva4/experiments/logs/Sprint-2/.ipynb_checkpoints/ (stored 0%)
#   adding: reva4/experiments/logs/Sprint-2/exp3_svar_results.json (deflated 76%)
#   adding: reva4/experiments/logs/Sprint-2/exp1_results.json (deflated 78%)
#   adding: reva4/experiments/logs/README.md (deflated 44%)
#   adding: reva4/experiments/logs/Sprint-1/ (stored 0%)
#   adding: reva4/experiments/logs/Sprint-1/exp4_stress_results.json (deflated 56%)
#   adding: reva4/experiments/logs/Sprint-1/exp5_comparison_results.json (deflated 67%)
#   adding: reva4/experiments/logs/Sprint-1/exp2_rlae_results.json (deflated 81%)
#   adding: reva4/experiments/logs/Sprint-1/exp3_svar_results.json (deflated 78%)
#   adding: reva4/experiments/logs/Sprint-1/exp1_results.json (deflated 78%)
#   adding: reva4/experiments/logs/.ipynb_checkpoints/ (stored 0%)
#   adding: reva4/colab-experiments/ (stored 0%)
#   adding: reva4/colab-experiments/Stage2_ILS_Experiment_Test2.ipynb (deflated 82%)
#   adding: reva4/colab-experiments/README.md (deflated 49%)
#   adding: reva4/colab-experiments/Stage1_Experiments.ipynb (deflated 81%)
#   adding: reva4/colab-experiments/Stage2_ILS_Experiment_Test1.ipynb (deflated 78%)
#   adding: reva4/reportdocx/ (stored 0%)
#   adding: reva4/reportdocx/alldocx/ (stored 0%)
#   adding: reva4/reportdocx/alldocx/rlae-doc.md (deflated 58%)
#   adding: reva4/reportdocx/alldocx/svar-doc.md (deflated 58%)
#   adding: reva4/reportdocx/README.md (deflated 33%)
#   adding: reva4/reportdocx/report_2025-12-31.docx (deflated 6%)
#   adding: reva4/project-scope/ (stored 0%)
#   adding: reva4/project-scope/README.md (deflated 34%)
#   adding: reva4/project-scope/svar-doc.pdf (deflated 6%)
#   adding: reva4/project-scope/rlae-svar-doc.pdf (deflated 9%)
